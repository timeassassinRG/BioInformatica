# %%
import pandas as pd
import numpy as np

# %%
file_path_expression_csv = '../data/COAD_expression.csv'
# Carico l'intero dataset di espressione genica
data_expression_full = pd.read_csv(file_path_expression_csv, sep=';')

# Visualizzo le prime righe per confermare il caricamento e la struttura dei dati
data_expression_full.head()
# Out:
#         GENE  TCGA-CA-6718-01A-11R-1839-07  TCGA-AD-6901-01A-11R-1928-07  \
# 0    5S_rRNA                             0                             2
# 1  5_8S_rRNA                             0                             0
# 2        7SK                             2                             1
# 3       A1BG                             3                             3
# 4   A1BG-AS1                            12                            10
#
#    TCGA-AA-A00J-01A-02R-A002-07  TCGA-CM-4752-01A-01R-1410-07  \
# 0                             1                             3
# 1                             0                            56
# 2                             0                             1
# 3                             0                             1
# 4                             4                             7
#
#    TCGA-AA-3549-01A-02R-0821-07  TCGA-AA-3966-01A-01R-1113-07  \
# 0                             0                             1
# ...

# %%
descriptive_stats = data_expression_full.describe(include=[np.number])
descriptive_stats.T
# Out:
#                                 count        mean           std  min  25%  \
# TCGA-CA-6718-01A-11R-1839-07  56500.0  867.960230   5156.344711  0.0  0.0
# TCGA-AD-6901-01A-11R-1928-07  56500.0  678.556195   4535.942066  0.0  0.0
# TCGA-AA-A00J-01A-02R-A002-07  56500.0  363.399558   3499.353447  0.0  0.0
# TCGA-CM-4752-01A-01R-1410-07  56500.0  353.761894   2692.857675  0.0  0.0
# TCGA-AA-3549-01A-02R-0821-07  56500.0  395.446903   3399.613001  0.0  0.0
# ...                               ...         ...           ...  ...  ...
# TCGA-CM-4748-01A-01R-1410-07  56500.0   25.777221    161.649513  0.0  0.0
# TCGA-G4-6295-01A-11R-1723-07  56500.0  661.787841   3922.441950  0.0  0.0
# TCGA-DM-A28C-01A-11R-A32Y-07  56500.0  921.466283  10941.825695  0.0  0.0
# TCGA-AZ-4682-01B-01R-A32Z-07  56500.0  959.311611   7731.108331  0.0  0.0
# TCGA-D5-6539-01A-11R-1723-07  56500.0  750.596425   5996.655441  0.0  0.0
#
#                               50%   75%        max
# ...
